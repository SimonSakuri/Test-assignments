# %%
import pandas as pd

data_train = pd.read_excel("BST.xlsx", header = None,names = ['Weekstart','Weekend','UAE_price','Competitor_price','Search','Search_new','Sales'])
data_train
# Out:
#      Weekstart     Weekend  UAE_price  Competitor_price  Search  Search_new  \
# 0   12.03.2018  18.03.2018  103197.80         125185.20    6382       12010
# 1   19.03.2018  25.03.2018  107808.30         111489.70    5218       10692
# 2   26.03.2018  01.04.2018   92518.58          98027.54    4986       10240
# 3   02.04.2018  08.04.2018   80068.75          98274.79    4523        6661
# 4   09.04.2018  15.04.2018   97560.45         128452.00    4105        5799
# 5   16.04.2018  22.04.2018   93533.10          97903.89    3327        4785
# 6   23.04.2018  29.04.2018  105465.40         111031.70    2546        3769
# 7   30.04.2018  06.05.2018  103581.30         109069.90    2703        3509
# 8   07.05.2018  13.05.2018   82913.93         106719.10    2490        3528
# 9   14.05.2018  20.05.2018  114749.30          93182.47    2644        3688
# 10  21.05.2018  27.05.2018   69152.92          89318.94    2533        3646
# ...

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
# %matplotlib inline


plt.figure(figsize=(15,6))
plt.plot(data_train.Weekend,data_train.UAE_price)
plt.plot(data_train.Weekend,data_train.Competitor_price)
plt.gcf().autofmt_xdate()
plt.legend(['UAE', 'Competitor'],loc=1)

# %%
plt.figure(figsize=(15,6))
plt.plot(data_train.Weekend, y,'*')
plt.plot(data_train.Weekend[5:42], lms.predict(Xs)[5:42],'b--')
plt.plot(data_train.Weekend[0:6], lms.predict(Xs)[0:6],'r')
plt.legend(['Actual','Fitted'])
plt.gcf().autofmt_xdate()

# %%
plt.figure(figsize=(15,10))
plt.subplot(211)
plt.plot(data_train.Weekend,data_train.Search)
plt.legend()
plt.gcf().autofmt_xdate()
plt.subplot(212)
plt.plot(data_train.Weekend,data_train.Search_new, color='red')
plt.legend()
plt.gcf().autofmt_xdate()

# %%
import seaborn as sns

plt.figure(figsize=(15,5))
plt.subplot(131)
sns.distplot(data_train.UAE_price)
plt.subplot(132)
sns.distplot(data_train.Competitor_price)
plt.subplot(133)
sns.distplot(data_train.Search_new)
# Out:
# C:\Python\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(5,5))
sns.distplot(data_train.Sales,color="blue")

# %%
corrm = data_train[['UAE_price','Competitor_price','Search','Search_new','Sales']]
correlation_matrix= corrm.corr().round(2)
sns.heatmap(data = correlation_matrix, annot = True)

# %%
#Regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
import numpy as np

X = data_train[['UAE_price','Competitor_price','Search_new']]
Xs= data_train[['UAE_price','Competitor_price','Search']] #old algo
y = data_train['Sales']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#Old model
Xs_train, Xs_test, y_train, y_test = train_test_split(Xs, y, test_size=0.33, random_state=42)
lms = LinearRegression()
lms.fit(Xs_train,y_train)
y_train_predict = lms.predict(Xs_train)
rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)
print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = lms.predict(Xs_test)
rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

print("Cross_val_score")
print("--------------------------------------")
print("Train cross_val_score R2",cross_val_score(lms, Xs_train, y_train, cv=5, scoring='r2'),cross_val_score(lm, Xs_train, y_train, cv=5, scoring='r2').mean())
print("Test cross_val_score R2", cross_val_score(lms, Xs_test, y_test, cv=5, scoring='r2'),cross_val_score(lm, Xs_test, y_test, cv=5, scoring='r2').mean())
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 11.771799116309134
# R2 score is 0.9304481378061722
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 12.728027420703693
# R2 score is 0.9054590434218177
#
#
# Cross_val_score
# --------------------------------------
# Train cross_val_score R2 [0.93707853 0.71734108 0.94318277 0.93412645 0.89745198] 0.885836160684169
# Test cross_val_score R2 [0.92986665 0.94903511 0.96806118 0.9524406  0.90964487] 0.9418096823758907

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
y_train_predict = lm.predict(X_train)
rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = lm.predict(X_test)
rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

print("Cross_val_score")
print("--------------------------------------")
print("Train cross_val_score R2",cross_val_score(lm, X_train, y_train, cv=5, scoring='r2'),cross_val_score(lm, X_train, y_train, cv=5, scoring='r2').mean())
print("Test cross_val_score R2", cross_val_score(lm, X_test, y_test, cv=5, scoring='r2'),cross_val_score(lm, X_test, y_test, cv=5, scoring='r2').mean())
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 9.404753947719636
# R2 score is 0.9556066464849917
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 8.798975058102714
# R2 score is 0.9548183631086457
#
#
# Cross_val_score
# --------------------------------------
# Train cross_val_score R2 [0.9874645  0.968065   0.79649955 0.96202887 0.95742486] 0.9342965539988441
# Test cross_val_score R2 [0.94189403 0.96181692 0.9643125  0.96913625 0.85140723] 0.9377133847538989

# %%
plt.figure(figsize=(15,6))
plt.plot(data_train.Weekend, y,'*')
plt.plot(data_train.Weekend, lms.predict(Xs),'r--')
plt.plot(data_train.Weekend, lm.predict(X),'b--')
plt.legend(['Actual','Old model','New model'])
plt.gcf().autofmt_xdate()

# %%
print (lm.intercept_,lm.coef_)
# Out:
# -21.20833409114306 [-0.00102171  0.00127642  0.01433653]

# %%
import statsmodels.api as sm
X_train = sm.add_constant(X_train)
model = sm.OLS(y_train,X_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.950
# Method:                 Least Squares   F-statistic:                     172.2
# Date:                Sun, 12 May 2019   Prob (F-statistic):           2.31e-16
# Time:                        20:17:04   Log-Likelihood:                -102.48
# No. Observations:                  28   AIC:                             213.0
# Df Residuals:                      24   BIC:                             218.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
#Прогноз
data_pred = pd.read_excel("BST_predict.xlsx", header = None,names = ['Weekstart','Weekend','UAE_price','Competitor_price','Search','Search_new'])
data_pred
# Out:
#     Weekstart     Weekend  UAE_price  Competitor_price  Search  Search_new
# 0  31.12.2018  06.01.2019  106651.70          96013.79    5270        6924
# 1  07.01.2019  13.01.2019  101673.50         102984.40    7902       10277
# 2  14.01.2019  20.01.2019  123099.70         103358.10    8145       10666
# 3  21.01.2019  27.01.2019  119102.70         125948.50    7169        9304
# 4  28.01.2019  03.02.2019  101896.10          91143.04    6908        8975
# 5  04.02.2019  10.02.2019  124413.50         107045.30    7193        9349
# 6  11.02.2019  17.02.2019  125538.70         110561.70    6620        8600
# 7  18.02.2019  24.02.2019  111693.30         110301.80    6520        8540
# 8  25.02.2019  03.03.2019  112086.90          95005.36    6650        9186
# 9  04.03.2019  10.03.2019   85283.17         103556.00    5393        7263

# %%
Xp = data_pred[['UAE_price','Competitor_price','Search_new']]
Xps = data_pred[['UAE_price','Competitor_price','Search']]
preds = lm.predict(Xp)
final_res=np.concatenate((lm.predict(X),lm.predict(Xp)))
final_data=np.concatenate((data_train.Weekend,data_pred.Weekend))

plt.figure(figsize=(15,5))
plt.plot(data_train.Weekend,y,'*')
plt.plot(data_train.Weekend,lm.predict(X),'b')
plt.plot(data_pred.Weekend,lms.predict(Xps),'r--')
plt.plot(final_data,final_res,'b--')
plt.legend(['Actual','Fitted','Old prediction','New prediction'])
plt.gcf().autofmt_xdate()

# %%
preds_round = [ int(x) for x in preds.round(0)]
data_pred['Predicted'] = preds_round
data_pred[['Weekstart','Weekend','Predicted']]
# Out:
#     Weekstart     Weekend  Predicted
# 0  31.12.2018  06.01.2019         92
# 1  07.01.2019  13.01.2019        154
# 2  14.01.2019  20.01.2019        138
# 3  21.01.2019  27.01.2019        151
# 4  28.01.2019  03.02.2019        120
# 5  04.02.2019  10.02.2019        122
# 6  11.02.2019  17.02.2019        115
# 7  18.02.2019  24.02.2019        128
# 8  25.02.2019  03.03.2019        117
# 9  04.03.2019  10.03.2019        128

# %%
def transform(doc):
    dif=[]
    aver = []
    ratio = []
    logsum = []
    for p in range(len(doc)):
        w0 = (doc.loc[ p,('UAE_price')] -doc.loc[p,('Competitor_price')])
        w1 = (doc.loc[ p,('UAE_price')] +doc.loc[p,('Competitor_price')])/2
        w2 = (doc.loc[ p,('UAE_price')]/doc.loc[p,('Competitor_price')])
        w3 = np.log(doc.loc[ p,('UAE_price')] +doc.loc[p,('Competitor_price')])
        dif.append(w0)
        aver.append(w1)
        ratio.append(w2)
        logsum.append(w3)
    result = np.dstack([sub,aver,ratio,logsum]).reshape(42,4)
    return result

# %%
def preproccesor(doc):
    dif=[]
    for p in range(len(doc)):
        w0 = (doc.loc[ p,('UAE_price')] -doc.loc[p,('Competitor_price')])
        dif.append(w0)
    return dif

# %%
trans = transform(data_train)
trans = pd.DataFrame(data = trans, columns=[['Difference','Average','Ratio','Logsum']])
trans["y"] = data_train["Sales"]
correlation_matrix = trans.corr().round(2)
sns.heatmap(data = correlation_matrix, annot = True)

# %%
show = data_train[['Weekstart','Weekend','Search_new','Sales']]
show['Diff'] = trans['Difference']
show = show[['Weekstart','Weekend','Search_new','Diff','Sales']]
show.head()
# Out:
# C:\Python\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Weekstart     Weekend  Search_new      Diff  Sales
# 0  12.03.2018  18.03.2018       12010 -21987.40    197
# 1  19.03.2018  25.03.2018       10692  -3681.40    155
# 2  26.03.2018  01.04.2018       10240  -5508.96    124
# 3  02.04.2018  08.04.2018        6661 -18206.04    131
# 4  09.04.2018  15.04.2018        5799 -30891.55    109

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures

# %%
Xn = show[['Diff','Search_new']]
y = show['Sales']

# %%
poly = PolynomialFeatures(2,interaction_only = True)
PX = poly.fit_transform(Xn)
X_train, X_test, y_train, y_test = train_test_split(PX, y, test_size=0.33, random_state=42)

# %%
data = pd.DataFrame(data = PX, columns = ['One','X1', 'X2', 'X1*X2'])
data['X1*X2'] = [int(x) for x in data['X1*X2'].round(2)]
data.head()
# Out:
#    One        X1       X2      X1*X2
# 0  1.0 -21987.40  12010.0 -264068674
# 1  1.0  -3681.40  10692.0  -39361528
# 2  1.0  -5508.96  10240.0  -56411750
# 3  1.0 -18206.04   6661.0 -121270432
# 4  1.0 -30891.55   5799.0 -179140098

# %%
#Нормировка признаков
X_scaler = StandardScaler()
X_train = X_scaler.fit_transform(X_train)
X_test = X_scaler.transform(X_test)

y_scaler = StandardScaler()
y_train = y_scaler.fit_transform(y_train[:, None])[:, 0]
y_test = y_scaler.transform(y_test[:, None])[:, 0]
# Out:
# C:\Python\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Python\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Python\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
#Гребневая регрессия
from sklearn.linear_model import Ridge

ridge = Ridge(alpha = 0.4, fit_intercept = True)
ridge.fit(X_train, y_train)
y_train_predict = ridge.predict(X_train)
rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = ridge.predict(X_test)
rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

print("Cross_val_score")
print("--------------------------------------")
print("Train cross_val_score R2",cross_val_score(ridge, X_train, y_train, cv=5, scoring='r2'),(cross_val_score(ridge, X_train, y_train, cv=5, scoring='r2')).mean())
print("Test cross_val_score R2", cross_val_score(ridge, X_test, y_test, cv=5, scoring='r2'),(cross_val_score(ridge, X_test, y_test, cv=5, scoring='r2')).mean())
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 0.20500772275020612
# R2 score is 0.9579718336127746
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 0.11455679714074682
# R2 score is 0.9847413386063385
#
#
# Cross_val_score
# --------------------------------------
# Train cross_val_score R2 [0.98085806 0.97406972 0.81549945 0.99194395 0.97191127] 0.9468564910069386
# Test cross_val_score R2 [0.96413971 0.97032098 0.98609787 0.98299475 0.75868684] 0.9324480301727807

# %%
print (ridge.intercept_,ridge.coef_)
# Out:
# -2.890038390096819e-17 [ 0.         -0.10448035  0.81969735 -0.30263959]

# %%
plt.figure(figsize=(15,6))
plt.plot(data_train.Weekend, y,'*')
plt.plot(data_train.Weekend, lm.predict(X),'r--')
plt.plot(data_train.Weekend, y_scaler.inverse_transform(ridge.predict(X_scaler.transform(poly.transform(Xn)))),'b--')
#plt.plot(data_train.Weekend, clf.predict(X),'g--')
#plt.plot(data_train.Weekend, model.predict(X),'b--')
plt.legend(['Actual','Linear regression','Ridge regression'])
plt.gcf().autofmt_xdate()

# %%
data_pred['Diff'] = preproccesor(data_pred)
Xp = data_pred[['Diff','Search_new']]
PXp = poly.transform(Xp)
final_res=np.concatenate((y_scaler.inverse_transform(ridge.predict(X_scaler.transform(PX))),y_scaler.inverse_transform(ridge.predict(X_scaler.transform(PXp)))))
final_data=np.concatenate((data_train.Weekend,data_pred.Weekend))

plt.figure(figsize=(15,5))
plt.plot(data_train.Weekend,y,'*')
plt.plot(data_train.Weekend,y_scaler.inverse_transform(ridge.predict(X_scaler.transform(PX))),'b')
plt.plot(data_pred.Weekend,lms.predict(Xps),'r--')
plt.plot(final_data,final_res,'b--')
plt.legend(['Actual','Fitted','Old prediction','New prediction'])
plt.gcf().autofmt_xdate()

# %%
preds = ridge.predict(X_scaler.transform(PXp))
preds = y_scaler.inverse_transform(preds)
preds_round = [int(x) for x in preds.round(0)]
data_pred['Predicted'] = preds_round
data_pred[['Weekstart','Weekend','Predicted']]
# Out:
#     Weekstart     Weekend  Predicted
# 0  31.12.2018  06.01.2019         95
# 1  07.01.2019  13.01.2019        153
# 2  14.01.2019  20.01.2019        132
# 3  21.01.2019  27.01.2019        146
# 4  28.01.2019  03.02.2019        122
# 5  04.02.2019  10.02.2019        119
# 6  11.02.2019  17.02.2019        112
# 7  18.02.2019  24.02.2019        126
# 8  25.02.2019  03.03.2019        117
# 9  04.03.2019  10.03.2019        127
